# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
import pprint
import string
from collections import Counter, OrderedDict
import math
# %matplotlib inline

# %% [markdown]
# ### dataset information

# %%
# read song lyrics by year csv
songs = pd.DataFrame()
for i in range(1962,2005):
    songs = pd.read_csv("./song_lyrics_year" +str(i)+ ".csv")
    # clean noisy data
    del songs['Unnamed: 0']
    songs = songs[songs['Lyrics']!='######']
    songs = songs.drop_duplicates('Lyrics')
    songs = songs[songs.Lyrics.str.contains('<') == False]
    songs.index = range(len(songs))
    print 'in year ', i
    print songs[['Artist', 'Title']].describe(include = 'all')
    print '-' * 50
# Out:
# in year  1962
#               Artist            Title
# count            110              110
# unique            72              109
# top     Howlin' Wolf  Hey Little Girl
# freq               6                2
# --------------------------------------------------
# in year  1963
#                        Artist        Title
# count                     165          165
# unique                     86          163
# top     Mississippi John Hurt  Casey Jones
# freq                        6            2
# --------------------------------------------------
# in year  1964
#                Artist                   Title
# count             226                     226
# unique             96                     222
# top     Chad & Jeremy  Anyone Who Had A Heart
# freq               10                       2
# --------------------------------------------------
# in year  1965
#                Artist                  Title
# count             231                    231
# ...
