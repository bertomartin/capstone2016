# %%
import pandas as pd

# %%
songs = pd.read_csv("./song_lyrics_filename515.csv")

# %%
songs.head()
# Out:
#               Artist                          Title  Lyrics
# 0  Unnatural Helpers                     Vox Humana  ######
# 1  Unnatural Helpers  Every Record Straight Tonight  ######
# 2  Unnatural Helpers         Tell Me That You Wanna  ######
# 3  Unnatural Helpers                Brave Dumb Face  ######
# 4  Unnatural Helpers                  Useful Things  ######

# %%
songs.head(50)
# Out:
#                        Artist                                         Title  \
# 0           Unnatural Helpers                                    Vox Humana
# 1           Unnatural Helpers                 Every Record Straight Tonight
# 2           Unnatural Helpers                        Tell Me That You Wanna
# 3           Unnatural Helpers                               Brave Dumb Face
# 4           Unnatural Helpers                                 Useful Things
# 5           Unnatural Helpers                       She Was Your Girlfriend
# 6                  Unter Null                                       Godless
# 7                  Unter Null                      Godless (NEIKKA RPM Mix)
# 8                  Unter Null                   Visceral_ Venom of My Being
# 9                  Unter Null               Get Your Mind Out of the Gutter
# 10                 Unter Null                                     Moving On
# ...

# %%
songs.tail(50)
# Out:
#                    Artist                                              Title  \
# 527         ZombieSuckers                               My Darling Zombified
# 528         ZombieSuckers                                       Ghoul Divine
# 529         ZombieSuckers                                  Graveyard A Go Go
# 530         ZombieSuckers                               The Nightmare Begins
# 531         ZombieSuckers                                        Blooderific
# 532         ZombieSuckers                                       Frankenstein
# 533         ZombieSuckers                            Attack Of The Cenobites
# 534         ZombieSuckers                            Pumpkin Patch Graveyard
# 535             [re:jazz]        Skin Against Skin (Against Savages Y Suefo)
# 536             [re:jazz]  Gabrielle Feat. Alice Russell (Kiko Navarro Ma...
# 537             [re:jazz]                                 Rita (Dusty Remix)
# ...

# %%
songs.ix[558]['Lyrics']
# Out:
# "Everybody's high on consolation\nEverybody's trying to tell me what is right for me, yeah\nMy daddy tried to bore me with a sermon\nBut it's plain to see that they can't comfort me\n\nSorry, Charlie, for the imposition\nI think I got (it got it), I got the strength to carry on, yeah\nI need a drink and a quick decision\nNow it's up to me, ooh, what will be\n\nShe's gone, she's gone \nOh I, oh I\nI better learn how to face it\nShe's gone, she's gone \nOh I, oh I\nI'd pay the devil to replace her\nShe's gone, and she's gone\nOh why, what went wrong?\n\nGet up in the morning, look in the mirror\nI'm worn as a toothbrush hanging in the stand, yeah\nMy face ain't looking any younger\nNow I can see love's taken a toll on me\n\nShe's gone, she's gone \nOh I, oh I\nI better learn how to face it\nShe's gone, and she's gone \nOh I, oh I\nI'd pay the devil to replace her\nShe's gone, she's gone\nOh why, what went wrong?\n\nThink I'll spend eternity in the city\nLet the carbon and monoxide chok
# ...
